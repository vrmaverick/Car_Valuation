# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
car_sales = pd.read_csv("./data/sale_dataset.csv")
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger                 NaN          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 3     71.4   196.6        3.850           18.0             22.0     3/10/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     9/21/2011
# 153   69.3   185.9        3.208           17.9             25.0    11/24/2012
# 154   69.3   186.2        3.259           17.9             25.0     6/25/2011
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2                  NaN
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %%
car_sales.dtypes,len(car_sales)
# Out:
# (Manufacturer            object
#  Model                   object
#  Sales_in_thousands     float64
#  __year_resale_value    float64
#  Vehicle_type            object
#  Price_in_thousands     float64
#  Engine_size            float64
#  Horsepower             float64
#  Wheelbase              float64
#  Width                  float64
#  Length                 float64
#  Curb_weight            float64
#  Fuel_capacity          float64
#  Fuel_efficiency        float64
#  Latest_Launch           object
#  Power_perf_factor      float64
#  dtype: object,
#  157)

# %%
car_sales['Latest_Launch'].value_counts() #it is not clear categorical
car_sales = car_sales.drop(['Latest_Launch','Sales_in_thousands','__year_resale_value','Horsepower','Wheelbase','Width','Length','Curb_weight','Fuel_capacity','Power_perf_factor'],axis=1)
car_sales.head()
# Out:
#   Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0        Acura  Integra    Passenger               21.50          1.8
# 1        Acura       TL    Passenger               28.40          3.2
# 2        Acura       CL    Passenger                 NaN          3.2
# 3        Acura       RL    Passenger               42.00          3.5
# 4         Audi       A4    Passenger               23.99          1.8
#
#    Fuel_efficiency
# 0             28.0
# 1             25.0
# 2             26.0
# 3             22.0
# 4             27.0

# %% [markdown]
# # Optimizing data for better results
# <br>
# <br>
#
#
# <li> Removing or Reducing dimensions for better accuracy and prevent overfitting of the model

# %%
# car_sales.drop(["Manufacturer","Model","__year_resale_value","Engine_size","Wheelbase","Width","Curb_weight"],axis =1,inplace =True)

# %%
car_sales
# Out:
#     Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0          Acura  Integra    Passenger               21.50          1.8
# 1          Acura       TL    Passenger               28.40          3.2
# 2          Acura       CL    Passenger                 NaN          3.2
# 3          Acura       RL    Passenger               42.00          3.5
# 4           Audi       A4    Passenger               23.99          1.8
# ..           ...      ...          ...                 ...          ...
# 152        Volvo      V40    Passenger               24.40          1.9
# 153        Volvo      S70    Passenger               27.50          2.4
# 154        Volvo      V70    Passenger               28.80          2.4
# 155        Volvo      C70    Passenger               45.50          2.3
# 156        Volvo      S80    Passenger               36.00          2.9
#
#      Fuel_efficiency
# 0               28.0
# 1               25.0
# 2               26.0
# 3               22.0
# 4               27.0
# ..               ...
# 152             25.0
# 153             25.0
# 154             25.0
# 155             23.0
# 156             24.0
#
# [157 rows x 6 columns]

# %% [markdown]
# # Cleaning Data

# %%
# column_means = car_sales.mean(axis=0)
# column_means
# car_sales['Sales_in_thousands'].mean()

# %%
for col in car_sales.columns:
    if car_sales[col].dtypes == 'float64':
        car_sales[col] = car_sales[col].fillna(car_sales[col].mean())
    else :
        car_sales[col].dropna()

# %%
car_sales.head()
# Out:
#   Manufacturer    Model Vehicle_type  Price_in_thousands  Engine_size  \
# 0        Acura  Integra    Passenger           21.500000          1.8
# 1        Acura       TL    Passenger           28.400000          3.2
# 2        Acura       CL    Passenger           27.390755          3.2
# 3        Acura       RL    Passenger           42.000000          3.5
# 4         Audi       A4    Passenger           23.990000          1.8
#
#    Fuel_efficiency
# 0             28.0
# 1             25.0
# 2             26.0
# 3             22.0
# 4             27.0

# %%
car_sales.isna().sum() #all null values resolved
# Out:
# Manufacturer          0
# Model                 0
# Vehicle_type          0
# Price_in_thousands    0
# Engine_size           0
# Fuel_efficiency       0
# dtype: int64

# %%
# spliting into X and Y
X = car_sales.drop("Price_in_thousands",axis =1)# all other factors are used for estimation

# %%
Y = car_sales["Price_in_thousands"] # Estimate the Power_Performance Factor

# %%
X.head()
# Out:
#   Manufacturer    Model Vehicle_type  Engine_size  Fuel_efficiency
# 0        Acura  Integra    Passenger          1.8             28.0
# 1        Acura       TL    Passenger          3.2             25.0
# 2        Acura       CL    Passenger          3.2             26.0
# 3        Acura       RL    Passenger          3.5             22.0
# 4         Audi       A4    Passenger          1.8             27.0

# %%
Y.head()
# Out:
# 0    21.500000
# 1    28.400000
# 2    27.390755
# 3    42.000000
# 4    23.990000
# Name: Price_in_thousands, dtype: float64

# %% [markdown]
# # Encoding Categorical Data

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

category = ["Vehicle_type","Model","Manufacturer"]#categorical labels
one_hot = OneHotEncoder() # instantiation
trans = ColumnTransformer([('one_hot',
                            one_hot,
                            category
                           )],remainder ='passthrough') # instantiation


X_new = trans.fit_transform(X)

# %%
import pickle
with open("./Trained_Model/encoder", "wb") as f: 
    pickle.dump(X_new, f)

# %%
# df = pd.DataFrame(trans.fit_transform(X).toarray()) #as it was giving tupple
# pd.DataFrame(trans.fit_transform(X))
# df
X_new_sparse = trans.fit_transform(X)  # Outputs a sparse matrix
X_new_dense = X_new_sparse.toarray()  # Convert sparse matrix to dense array

X_new = trans.fit_transform(X)

print(X_new)
# Out:
#   (0, 1)	1.0
#   (0, 81)	1.0
#   (0, 158)	1.0
#   (0, 188)	1.8
#   (0, 189)	28.0
#   (1, 1)	1.0
#   (1, 145)	1.0
#   (1, 158)	1.0
#   (1, 188)	3.2
#   (1, 189)	25.0
#   (2, 1)	1.0
#   (2, 27)	1.0
#   (2, 158)	1.0
#   (2, 188)	3.2
#   (2, 189)	26.0
#   (3, 1)	1.0
#   (3, 117)	1.0
#   (3, 158)	1.0
#   (3, 188)	3.5
#   (3, 189)	22.0
#   (4, 1)	1.0
#   (4, 10)	1.0
#   (4, 159)	1.0
#   (4, 188)	1.8
#   (4, 189)	27.0
#   :	:
#   (152, 1)	1.0
#   (152, 150)	1.0
#   (152, 187)	1.0
#   (152, 188)	1.9
#   (152, 189)	25.0
#   (153, 1)	1.0
#   (153, 127)	1.0
#   (153, 187)	1.0
#   (153, 188)	2.4
#   (153, 189)	25.0
#   (154, 1)	1.0
#   (154, 151)	1.0
#   (154, 187)	1.0
#   (154, 188)	2.4
#   (154, 189)	25.0
#   (155, 1)	1.0
#   (155, 26)	1.0
#   (155, 187)	1.0
#   (155, 188)	2.3
#   (155, 189)	23.0
#   (156, 1)	1.0
#   (156, 128)	1.0
#   (156, 187)	1.0
#   (156, 188)	2.9
#   (156, 189)	24.0

# %% [markdown]
#  <b> Alternate method :</b>

# %%
dum = pd.get_dummies(car_sales[["Vehicle_type"]])
dum
# Out:
#      Vehicle_type_Car  Vehicle_type_Passenger
# 0               False                    True
# 1               False                    True
# 2               False                    True
# 3               False                    True
# 4               False                    True
# ..                ...                     ...
# 152             False                    True
# 153             False                    True
# 154             False                    True
# 155             False                    True
# 156             False                    True
#
# [157 rows x 2 columns]

# %% [markdown]
# # Dividing Dataset

# %%
#Split into training and testing
from sklearn.model_selection import train_test_split

# %%
np.random.seed(29)
X_train,X_test,Y_train,Y_test = train_test_split(X_new,Y,test_size=0.1)

# %%
type(X_train),type(Y_train)
# Out:
# (scipy.sparse._csr.csr_matrix, pandas.core.series.Series)

# %% [markdown]
# # Training a Regression Model

# %%
# Building a regressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR 
import matplotlib.pyplot as plt 

# Assuming you have your training data X_new and target variable Y

# Define models as dictionary entries for easier iteration
models = {
    'Random Forest': Pipeline([('regressor', RandomForestRegressor())]),
    'Ridge Regression': Pipeline([('regressor', Ridge())]),
    'Lasso Regression': Pipeline([('regressor', Lasso())]),
    'Support Vector Regression': Pipeline([('regressor', SVR())])
}

# Define a common hyperparameter grid for all models (you might need to adjust based on the models)
param_grid = {
    'Random Forest': {
        'regressor__n_estimators': [100, 200, 300], 
        'regressor__max_depth': [None, 10, 20]      
    },
    'Ridge Regression': {
        'regressor__alpha': [0.01, 0.1, 1.0]       
    },
    'Lasso Regression': {
        'regressor__alpha': [0.01, 0.1, 1.0]      
    },
    'Support Vector Regression': {
        'regressor__C': [0.1, 1.0, 10.0],           
        'regressor__kernel': ['linear', 'rbf']     
    }
}

# Perform GridSearchCV for each model
best_models = {}
for model_name, model in models.items():
    grid_search = GridSearchCV(model, param_grid[model_name], cv=5, n_jobs=-1)
    grid_search.fit(X_new,Y)
    # grid_search.fit(X_train, Y_train)
    best_models[model_name] = grid_search.best_estimator_

# Evaluate and compare the best models (choose your preferred evaluation metric)
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score  # Example metric

for model_name, model in best_models.items():
    y_pred = model.predict(X_new)  # Make predictions

    # Calculate MSE and MAE
    mse = mean_squared_error(Y, y_pred)
    mae = mean_absolute_error(Y, y_pred)

    # Accuracy for regression is not directly applicable, but you can consider R-squared
    r2 = r2_score(Y, y_pred)

    print(f"{model_name}:")
    print(f"\tMSE: {mse:.4f}")
    print(f"\tMAE: {mae:.4f}")
    print(f"\tR-squared: {r2:.4f}")
# Out:
# Random Forest:
# 	MSE: 10.0604
# 	MAE: 1.9459
# 	R-squared: 0.9502
# Ridge Regression:
# 	MSE: 0.3060
# 	MAE: 0.3876
# 	R-squared: 0.9985
# Lasso Regression:
# 	MSE: 35.7025
# 	MAE: 4.3625
# 	R-squared: 0.8233
# Support Vector Regression:
# 	MSE: 5.4015
# 	MAE: 0.6531
# 	R-squared: 0.9733

# %%
# Store model names and metrics for bar plots
model_names = list(best_models.keys())
mse_values = [mean_squared_error(Y, best_models[model_name].predict(X_new)) for model_name in model_names]
mae_values = [mean_absolute_error(Y, best_models[model_name].predict(X_new)) for model_name in model_names]
r2_values = [r2_score(Y, best_models[model_name].predict(X_new)) for model_name in model_names]
plt.figure(figsize=(20, 4))

# MSE bar plot
plt.subplot(1, 3, 1)
plt.bar(model_names, mse_values)
plt.title("MSE Comparison")
plt.xlabel("Model Name")
plt.ylabel("MSE")

# MAE bar plot
plt.subplot(1, 3, 2)
plt.bar(model_names, mae_values)
plt.title("MAE Comparison")
plt.xlabel("Model Name")
plt.ylabel("MAE")

# R-squared bar plot
plt.subplot(1, 3, 3)
plt.bar(model_names, r2_values)
plt.title("R-squared Comparison")
plt.xlabel("Model Name")
plt.ylabel("R-squared")

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
best_model = grid_search.best_estimator_
val_score = best_model.score(X_test, Y_test)
val_score
# Out:
# 0.9769369841641817

# %%
# model.fit(X_train,Y_train)

# %%
# model.score(X_test,Y_test)

# %% [markdown]
# <b> Good Regression Model as its score closer to 1 </b>
#
# <li> Results are Accurate and Thus we can say the Predictions by the model have high Probablity of being True values

# %%
Y_predict = best_model.predict(X_new)
analyse =  pd.DataFrame(Y_predict,columns=["Predicted Values"])
analyse['Actual Price'] = Y

# %%
analyse
# Out:
#      Predicted Values  Actual Price
# 0           21.401631     21.500000
# 1           28.498334     28.400000
# 2           27.489104     27.390755
# 3           41.899909     42.000000
# 4           24.091584     23.990000
# ..                ...           ...
# 152         24.499318     24.400000
# 153         27.599257     27.500000
# 154         28.899319     28.800000
# 155         39.452730     45.500000
# 156         35.901400     36.000000
#
# [157 rows x 2 columns]

# %%
plt.style.use("seaborn-whitegrid")
fig,ax = plt.subplots(figsize=(7,7))
ax.scatter(Y,Y_predict)
ax.set_xlim([30,100])
ax.set_ylim([30,90])
# ax.set(xlabel="Actual",ylabel="Predicted")
ax.plot(Y_test,Y_test,c="red")
ax.set_xlabel("Actual Price",fontweight = "bold",fontsize=13)
ax.set_ylabel("Prediction Predicted",fontweight = "bold",fontsize=13)
fig.suptitle("Accuracy of Prediction",fontweight = "bold",fontsize=16);

# %%
import pickle

# %%
pickle.dump(best_model,open('./Trained_Model/Car_Performance_Model.pkl','wb'))

# %%
fig.savefig('PerformaceModel.png')
